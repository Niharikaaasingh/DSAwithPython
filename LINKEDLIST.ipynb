# %% [markdown]
# <a href="https://colab.research.google.com/github/Niharikaaasingh/DSAwithPython/blob/main/LINKEDLIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None
a = Node(10)
b = Node(7)
c = Node(3)

a.next = b
b.next = c
head = a

print(head.data)
print(head.next.data)
print(head.next.next.data)
# Out:
# 10
# 7
# 3

# %% [markdown]
# #Traversal in a Linkedlist

# %%
def LinkedListTraversal(head):
  curr = head
  while curr != None:
    print(curr.data,end =" ")
    curr = curr.next
LinkedListTraversal(head)
# Out:
# 10 7 3

# %% [markdown]
# #Insertion in Linkedlist

# %%
#Insertion at begining of node
newNode = Node(4)
newNode.next = head
head = newNode
LinkedListTraversal(head)
# Out:
# 4 10 7 3

# %%
#Insertion at end of Node
newNode= Node(45)
curr = head
while curr.next != None:
  curr = curr.next
curr.next = newNode
LinkedListTraversal(head)
# Out:
# 4 10 7 3 45

# %%
#Insertion at kth index
newNode = Node(4)
k = 2
curr = head
for i in range (k-1):
  curr = curr.next
newNode.next = curr.next
curr.next = newNode
LinkedListTraversal(head)
# Out:
# 4 10 4 7 3 45

# %% [markdown]
# #Deletion in LinkedList

# %%
#delete 1st node
head = head.next
LinkedListTraversal(head)
# Out:
# 10 4 7 3 45

# %%
#delete last node
curr = head
while curr.next.next != None:
  curr = curr.next
curr.next = None
LinkedListTraversal(head)
# Out:
# 10 4 7 3

# %%
#delete node at kth index
k = 2
curr = head
for i in range (k-1):
  curr = curr.next
curr.next = curr.next.next
LinkedListTraversal(head)
# Out:
# 10 4 3

# %%
#insert linked list
newNode = Node(99)
k = 2
curr = head
for i in range (k-1):
  curr = curr.next
newNode.next = curr.next
curr.next = newNode
LinkedListTraversal(head)
# Out:
# 10 4 99 24 13 9 4 3

# %% [markdown]
# #876. Middle of the Linked List
# Given the head of a singly linked list, return the middle node of the linked list.
#
# If there are two middle nodes, return the second middle node.

# %%
#there are two methods for this questions soli=ution one is generic and 2nd is slow and fast pointer
#method 1
curr = head
l = 0
while curr != None:
  curr = curr.next
  l+=1
curr = head
for i in range(l//2):
  curr = curr.next
print(curr.data)
# Out:
# 13

# %%
#method 2
slow = head
fast = head
while fast!= None and fast.next != None:
  slow = slow.next
  fast = fast.next.next
print(slow.data)
# Out:
# 13

# %% [markdown]
# #237. Delete Node in a Linked List
#
# There is a singly-linked list head and we want to delete a node node in it.
# You are given the node to be deleted node. You will not be given access to the first node of head.
# All the values of the linked list are unique, and it is guaranteed that the given node node is not the last node in the linked list
# Delete the given node. Note that by deleting the node, we do not mean removing it from memory. We mean:
# The value of the given node should not exist in the linked list.
# The number of nodes in the linked list should decrease by one.
# All the values before node should be in the same order.
# All the values after node should be in the same order.
# Custom testing:
# For the input, you should provide the entire linked list head and the node to be given node. node should not be the last node of the list and should be an actual node in the list.
# We will build the linked list and pass the node to your function.
# The output will be the entire list after calling your function.

# %%
class Solution:
    def deleteNode(self, node):
        """
        :type node: ListNode
        :rtype: void Do not return anything, modify node in-place instead.
        """
        node.val = node.next.val
        node.next = node.next.next

# %% [markdown]
# #Leetcode 19. Remove Nth Node From End of List
# Given the head of a linked list, remove the nth node from the end of the list and return its head.

# %%
class Solution:
    def removeNthFromEnd(self,head, n):
        p1 = head
        p2 = head

        for i in range(n):
            p2 = p2.next
        if p2 == None:
            head = head.next
            return head
        while p2.next != None:
            p2 = p2.next
            p1 = p1.next
        p1.next = p1.next.next
        return(head)

# %% [markdown]
# #83. Remove Duplicates from Sorted List
# Given the head of a sorted linked list, delete all duplicates such that each element appears only once. Return the linked list sorted as well.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def deleteDuplicates(self, head):
        if head == None and curr.next == None:
            return head
        curr = head
        while curr != None and curr.next != None:
            if curr.next.val == curr.val:
                curr.next = curr.next.next
            else:
                curr = curr.next
        return head

# %% [markdown]
# #206. Reverse Linked List
# Given the head of a singly linked list, reverse the list, and return the reversed list.
